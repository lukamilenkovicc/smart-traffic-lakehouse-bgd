# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.fetch_gtfs import fetch_gtfs
from src.fetch_openaq_locations import fetch_openaq_locations

print("\n GTFS preuzimanje...")
fetch_gtfs()

print("\n Preuzimanje OpenAQ lokacija...")
fetch_openaq_locations()

# %%
# %sql
SELECT * FROM bg_traffic.bg_traffic_bronze.openaq_measurements;
